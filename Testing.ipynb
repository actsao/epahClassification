# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pywt
from scipy.io import loadmat

import csv
import os

# %%
df = pd.read_csv('labels.csv')
df
# Out:
#      RHC_or_CPET        Filename   Source
# 0              0  HJ6108_WAV_004  control
# 1              1   EL692_WAV_002  control
# 2              1   EL692_WAV_006  control
# 3              1   EL692_WAV_046  control
# 4              1   EL692_WAV_050  control
# ..           ...             ...      ...
# 185            0  HH3542_WAV_004     epah
# 186            1   EL212_WAV_000     epah
# 187            1   EL212_WAV_004     epah
# 188            1   EL212_WAV_032     epah
# 189            1   EL212_WAV_036     epah
#
# [190 rows x 3 columns]

# %%
# files = [f'waveforms/{f}' for f in os.listdir('waveforms') if 'clean' in f and 'diast' not in f and 'trended' not in f]
# filenames_from_folder = [f for f in os.listdir('waveforms')]
# len(filenames_from_folder)

# %%
filenames_from_folder = [f for f in os.listdir('waveforms')]
df['File_Exists'] = [filename.split('_')[0] in filenames_from_folder for filename in df['Filename']]
df['RHC_and_Exists'] = ~df['RHC_or_CPET'] & df['File_Exists']

# %%
[filename.split('_')[0] in filenames_from_folder for filename in df['Filename']]
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
df[df['RHC_or_CPET'] == 1]
# Out:
#      RHC_or_CPET        Filename   Source  File_Exists  RHC_and_Exists
# 1              1   EL692_WAV_002  control        False           False
# 2              1   EL692_WAV_006  control        False           False
# 3              1   EL692_WAV_046  control        False           False
# 4              1   EL692_WAV_050  control        False           False
# 5              1   EL692_WAV_054  control        False           False
# ..           ...             ...      ...          ...             ...
# 178            1  EL1117_WAV_040     epah        False           False
# 186            1   EL212_WAV_000     epah        False           False
# 187            1   EL212_WAV_004     epah        False           False
# 188            1   EL212_WAV_032     epah        False           False
# 189            1   EL212_WAV_036     epah        False           False
#
# [160 rows x 5 columns]
